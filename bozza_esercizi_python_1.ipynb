# %%
stringa = "ciao"
numeri = [1,2,3,4]

numeri[2] = 5

# sto facendo vedere lo slice
# stringa[1:3]

# stringa[1] + stringa[2]
# numeri[1] + numeri[2]

# stringa.find("a")
stringa2 = stringa.replace("c","m")
# stringa2

stringa.split('a')

lista1 = ["c 3", 34, 22.0, "sadf", [1,2,3], [1,2,"sdf"]]
# lista1[0].split()
# lista1[4][2]
# lista1.remove("c 3")
lista1


# stringa_tupla = ("ciao")
# stringa_tupla
numeri_tupla = (1,2,3)

lista2 = list(numeri_tupla)
lista2[2] = 'r'
numeri_tupla = tuple(lista2)
# numeri_tupla

# if (len(numeri_tupla) >= 4) {
#     print("ciao")
#     }
    
numeri_tupla = ()

# if len(numeri_tupla) == 2:
#     print("A")
# elif len(numeri_tupla) == 3:
#     print("B")
# else:
#     print("C")

# print("ciao")

list1 = [1,2,3,4,4,4,5,5,6,6,7]
set(list1)
list2 = list1[3:8]

# set(list1) & set(list2)

diz = {} # dict() elementi k:v
diz = {1:"gatto", 2:"cane", 3:"uccello", 4:"topo"}
# diz.popitem()
# diz.pop(2)
# diz
# diz[8] = "anatra"
# diz[7] = "anatra"
# diz[1] = "super gatto"
# diz["super gatto"] = "£asdf"
# diz.items()

list1 = ["zero", "uno", "due", "tre", "quattro"]

# print(list1)
# range(4,5)

N = len(list1)

# for (int i=0; i<N; i++) {
#     # print(i)  # stampa gli indici
#     print(list1[i])  # stampa i valori della lista in corrisp. dell'indice stesso
    
# }
# for i in range(0,N): # [0,1,2,3]
    # print("indice ",i, "valore", list1[i])

# for i in list1:
    # print("valore", i)

# enumerate([1,2]) # torna [ [0,1], [1,2] ]

# for i,v in enumerate(list1):
    # print(i,v)
  
## nel caso di dizionari
diz = {1:"gatto", 2:"cane", 3:"uccello", 4:"topo"}
# for k in diz: # for k in diz.key()
    # print(k)

# for k,v in diz.items(): # for k in diz.key()
    # print("la chiave è",k, "il valore è", v)

# for i=0; i<lunghezzadizionario; i++ {
    # if 1 == diz[i]
        # return True   
# }

# if 1 in diz:
#     print("trovato")
#     diz[1] = "gatto 2"
# else:
#     print("non trovato")

i = 0
# while i<10:
#     print(i)
#     i = i + 1 # i+=1

# for i in range(10):
#   if i != 5:
#       print(i)

# for i in range(10):
#   if i == 5:
#     print("sto saltando il numero", i)
#     continue
#   print(i)

# for i in range(10):
#   if i == 5:
#     print("tanti saluti sono al numero", i)
#     break
#   print(i)

# lista3 = list(range(10))
# lista3

# stampa numeri da 0 a 10 non multipli di 2
for i in range(10):
    if not(i % 2 == 0):  # not nega una condiz. e / torna il resto
      print(i)

print("----")

for i in range(10):
    if i % 2 != 0:  # / torna il resto
      print(i)

print("----")

for i in range(10):
    if i % 2 == 0:  # / torna il resto
      pass
    else:
      print(i)

# %%
"""
Esercizio 03: dizionari, costrutti condizionali ed iterativi
Sostituire allo statement 'pass' il codice corretto
"""

# Giocare a FizzBuzz con i numeri da 1 a 50. Le regole sono le seguenti:
# Se il numero è multiplo di 3 mostrare la stringa 'fizz'
# se il numero è multiplo di 5 mostrare la stringa 'buzz'
# se il numero è multiplo sia di 3 che di 5 mostrare la stringa 'fizzbuzz'
# se il numero non è multiplo nè di 3 nè di 5 mostrare il numero
# Output atteso:
# 1, 2, fizz, 4, buzz, fizz, 7, 8, fizz, buzz, 11, fizz, ...

for i in range(1,51):
    if i % 5 == 0 and i % 3 == 0:
      print("fizzbuzz")
    elif i % 3 == 0:
      print("fizz")
    elif i % 5 == 0:
      print("buzz")
    else:
      print(i)
    print(", ")

# creare un dizionario che contenga come chiavi i nomi 'jack' e 'steve' e come
# rispettivi valori i numeri di telefono interno 4098 e 4139
# metodo 1
# diz = {}
# diz["jack"] = 4098
# diz["steve"] = 4139
# metodo 2
# diz = {"jack":4098, "steve": 4139}
# metodo 3
diz = {}
# for k in [("jack", 4098), ("steve", 4139)]:
  # diz[k[0]] = k[1]
for k,v in [["jack", 4098], ["steve", 4139]]:
# for k,v in [("jack", 4098), ("steve", 4139)]:
  diz[k] = v
print(diz)


# aggiungere un elemento 'guido' con valore 4139
diz["guido"] = 4139
print(diz)

#eliminare l'elemento di chiave 'steve'
diz.pop("steve")
print(diz)

# stampare il dictionary
print(diz)
for k,v in diz.items():
    print(k,v)

# stampare solo le chiavi
for d in diz:
    print(d)
for d in diz.keys():
    print(d)

# stampo True se la chiave 'guido' e' presente
# diz.pop("guido")
if "guido" in diz:
    print(True)

#Stampo tutte le coppie chiave - valore nel formato:
# chiave: 'guido', valore: 4127
#Quante alternative ho? 
for k,v in diz.items():
    print("chiave:",k,"valore:",v)

# Mostrare a video se le chiavi con valore 'jack', 'steve' e 'guido' sono presenti nel dizionario
# con una frase del tipo  "La chiave XX [non] è presente nel dizionario"

for k in ["jack", "steve", "guido"]:
    if k in diz:
        print(k, "è presente")
    else:
        print(k, "non è presente")

# %%
# AND
# cond1 and cond2 == res
# True and True == True
# True and False == False
# False and True == False
# False and False == False

# OR
# cond1 or cond2 == res
# True or True == True
# True or False == True
# False or True == True
# False or False == False

# NOT
# not cond ==  res
# not True == False
# not True  == False
# not False == True
# not False  == True

cond1 = True
cond2 = False

# cond1 and cond2 and not cond1 and (cond2 or cond1)
# cond1 and cond2 -> False
# False and not cond1 -> False
# (cond2 or cond1) -> True
# False and False and True -> Fase

# %%
#Es 2
#prendere il testo "Python is a widely used high level, general purpose, dynamic programming language - its design philosophy features code readability, and its syntax allows a programming style that express concepts in fewer lines of code than would be possible in another language. The language provides constructs to enable clear programs on both a small and large scale. Python supports multiple programming paradigms and it features a dynamic type system and automatic memory management and it has a large and comprehensive standard library."

#e stampare la frequenza (numero di occorrenze) di ogni parola 

testo = "Python is a widely used high level, general purpose, dynamic programming language - its design philosophy features code readability, and its syntax allows a programming style that express concepts in fewer lines of code than would be possible in another language. The language provides constructs to enable clear programs on both a small and large scale. Python supports multiple programming paradigms and it features a dynamic type system and automatic memory management and it has a large and comprehensive standard library."

# testo.replace(",","").replace(".", "").replace("!", "").split()
for p in [".", ",", "!", "?", ";", ":"]:
    testo = testo.replace(p,"")

testo = testo.split()

# metodo 1
# for t in set(testo):
#     print(t, "presente", testo.count(t), "volte")

# metodo 2
diz = {}
for k in set(testo):
    diz[k] = 0

for s in testo:
    v = diz[s]
    v = v + 1
    diz[s] = v

for k,v in diz.items():
    print(k, "presente", v, "volte")

# %%
import random
N = 10

# creare un lista di N numeri interi casuali, ogni numero compreso tra 0 e 100
# creare 2 nuove liste, una composta da numeri pari e una dai dispari
# se un numero è dispari e nultiplo di 3 lo saltiamo
# sortare le due liste e stamparle

lista = []
lista_pari = []
lista_dispari = []

for i in range(N):
    lista.append(random.randint(0,100))

for num in lista:
    if num % 2 == 0:
        lista_pari.append(num)
    # else:
        # if not num % 3 == 0:
            # lista_dispari.append(num)
    elif num % 2 != 0 and not num % 3 == 0:
        lista_dispari.append(num)

print(lista_dispari)
print(lista_pari)

random.random()
# Out:
# [47, 13, 95, 91, 61, 53]
# [34, 6, 0]
# 0.45296721129729844
